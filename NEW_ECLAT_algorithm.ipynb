# %% [markdown]
# Here's a pseudocode of the ECLAT algorithm:

# %% [markdown]
# The ECLAT (Equivalence Class Clustering and bottom-up Lattice Traversal) algorithm is used to identify frequent item sets in transactional data. Here is the pseudocode for the ECLAT algorithm:
#
# Initialize an empty item set (L)
#
# For each transaction in the transactional data:
#   a. Get the items in the transaction and sort them in lexicographical order
#   b. Add the items to the item set (L)
#
# Initialize a dictionary (D) to store the frequent items and their support count
#
# For each item in the item set (L):
#   a. Count the number of transactions that contain the item
#   b. If the support count of the item is greater than or equal to the minimum support threshold, add the item to the dictionary (D)
#
# For each item in the dictionary (D), find its frequent item sets by:
# a. Generating all possible combinations of items
# b. Counting the number of transactions that contain each combination
# c. If the support count of the combination is greater than or equal to the minimum support threshold, add the combination to the dictionary (D)
#
# Return the frequent item sets in the dictionary (D)

# %%
def read_dataset(file_path):
    """
    This function reads the dataset from a text file. 
    Each line in the file represents a transaction, and the numbers in each line are separated by a space.
    The function returns a list of transactions where each transaction is represented as a set.

    Parameters:
    file_path (str): The path to the text file containing the dataset.

    Returns:
    list: A list of transactions, each represented as a set.
    """
    transactions = []
    with open(file_path, 'r') as f:
        for line in f:
            transaction = set(map(int, line.strip().split()))
            transactions.append(transaction)
    return transactions

# %%
def eclat(dataset, min_support=1):
    # Find all items in the dataset
    items = set()
    for transaction in dataset:
        for item in transaction:
            items.add(item)

    # Create a list of items and sort them by frequency
    item_list = list(items)
    item_list.sort(key=lambda x: sum([1 for transaction in dataset if x in transaction]), reverse=True)

    # Get frequent itemsets
    result = []
    for i in range(len(item_list)):
        eclat_recursive(dataset, [item_list[i]], i, item_list, min_support, result)

    # Return frequent itemsets
    return result

def eclat_recursive(dataset, prefix, prefix_index, item_list, min_support, result):
    # Find prefix support
    prefix_support = sum([1 for transaction in dataset if all(item in transaction for item in prefix)])

    # If prefix support is greater than or equal to minimum support
    if prefix_support >= min_support:
        # Add prefix to result
        result.append((prefix, prefix_support))

        # For each item after the prefix in the item list
        for i in range(prefix_index + 1, len(item_list)):
            # Find support for item
            item_support = sum([1 for transaction in dataset if item_list[i] in transaction])

            # If item support is greater than or equal to minimum support
            if item_support >= min_support:
                # Call eclat_recursive with item appended to prefix
                eclat_recursive(dataset, prefix + [item_list[i]], i, item_list, min_support, result)

#Example usage
# dataset = [
#     [1, 2, 3],
#     [1, 2, 4],
#     [2, 3, 4],
#     [2, 3],
#     [1, 2],
#     [1, 3],
#     [2, 4]
# ]

# %%
transactions = read_dataset('dataset.txt')

min_support = 4

# frequent_itemsets = eclat(dataset, min_support)
frequent_itemsets = eclat(transactions, min_support)

for frequent_itemset, support in frequent_itemsets:
    print("Item Set: {} Support: {}".format(frequent_itemset, support))
# Out:
# Streaming output truncated to the last 5000 lines.
# Item Set: [19, 21, 74] Support: 4
# Item Set: [19, 21, 120] Support: 4
# Item Set: [19, 21, 53] Support: 4
# Item Set: [19, 21, 97] Support: 4
# Item Set: [19, 42] Support: 7
# Item Set: [19, 62] Support: 18
# Item Set: [19, 62, 112] Support: 4
# Item Set: [19, 62, 120] Support: 6
# Item Set: [19, 62, 6] Support: 4
# Item Set: [19, 62, 88] Support: 5
# Item Set: [19, 62, 118] Support: 4
# Item Set: [19, 62, 22] Support: 6
# Item Set: [19, 62, 17] Support: 4
# Item Set: [19, 62, 7] Support: 5
# Item Set: [19, 62, 93] Support: 4
# Item Set: [19, 62, 76] Support: 5
# Item Set: [19, 62, 35] Support: 4
# Item Set: [19, 62, 109] Support: 4
# Item Set: [19, 62, 111] Support: 4
# Item Set: [19, 62, 20] Support: 4
# Item Set: [19, 72] Support: 9
# Item Set: [19, 74] Support: 17
# Item Set: [19, 74, 97] Support: 4
# Item Set: [19, 74, 2] Support: 5
# Item Set: [19, 74, 5] Support: 4
# Item Set: [19, 74, 29] Support: 4
# Item Set: [19, 74, 59] Support: 4
# Item Set: [19, 74, 93] Support: 5
# Item Set: [19, 74, 106] Support: 4
# Item Set: [19, 74, 76] Support: 4
# Item Set: [19, 74, 27] Support: 4
# Item Set: [19, 74, 89] Support: 4
# Item Set: [19, 74, 25] Support: 4
# Item Set: [19, 80] Support: 11
# Item Set: [19, 92] Support: 14
# Item Set: [19, 92, 120] Support: 6
# Item Set: [19, 92, 119] Support: 4
# Item Set: [19, 92, 93] Support: 7
# Item Set: [19, 92, 33] Support: 4
# Item Set: [19, 94] Support: 10
# Item Set: [19, 94, 5] Support: 4
# Item Set: [19, 112] Support: 10
# Item Set: [19, 120] Support: 17
# Item Set: [19, 120, 104] Support: 5
# Item Set: [19, 120, 90] Support: 4
# Item Set: [19, 120, 15] Support: 4
# Item Set: [19, 120, 17] Support: 4
# Item Set: [19, 120, 84] Support: 4
# Item Set: [19, 120, 119] Support: 5
# Item Set: [19, 120, 7] Support: 6
# Item Set: [19, 120, 113] Support: 4
# Item Set: [19, 120, 27] Support: 4
# Item Set: [19, 120, 35] Support: 4
# Item Set: [19, 120, 20] Support: 5
# Item Set: [19, 6] Support: 12
# Item Set: [19, 6, 90] Support: 4
# Item Set: [19, 6, 4] Support: 4
# Item Set: [19, 6, 7] Support: 4
# Item Set: [19, 41] Support: 8
# Item Set: [19, 57] Support: 9
# Item Set: [19, 57, 17] Support: 4
# Item Set: [19, 57, 49] Support: 4
# Item Set: [19, 88] Support: 13
# Item Set: [19, 88, 17] Support: 4
# Item Set: [19, 88, 64] Support: 4
# Item Set: [19, 88, 35] Support: 6
# Item Set: [19, 88, 111] Support: 4
# Item Set: [19, 104] Support: 14
# Item Set: [19, 104, 7] Support: 5
# Item Set: [19, 104, 49] Support: 4
# Item Set: [19, 104, 113] Support: 4
# Item Set: [19, 116] Support: 6
# Item Set: [19, 118] Support: 10
# Item Set: [19, 9] Support: 7
# Item Set: [19, 22] Support: 15
# Item Set: [19, 22, 17] Support: 5
# Item Set: [19, 22, 59] Support: 4
# Item Set: [19, 22, 106] Support: 6
# Item Set: [19, 22, 14] Support: 4
# Item Set: [19, 26] Support: 12
# Item Set: [19, 36] Support: 12
# Item Set: [19, 36, 29] Support: 4
# Item Set: [19, 36, 93] Support: 4
# Item Set: [19, 36, 82] Support: 4
# Item Set: [19, 48] Support: 11
# Item Set: [19, 48, 93] Support: 4
# Item Set: [19, 90] Support: 8
# Item Set: [19, 103] Support: 11
# Item Set: [19, 103, 43] Support: 4
# Item Set: [19, 117] Support: 11
# Item Set: [19, 117, 53] Support: 6
# Item Set: [19, 117, 2] Support: 4
# Item Set: [19, 117, 76] Support: 4
# Item Set: [19, 53] Support: 11
# Item Set: [19, 53, 85] Support: 4
# Item Set: [19, 70] Support: 7
# Item Set: [19, 85] Support: 11
# Item Set: [19, 97] Support: 11
# Item Set: [19, 105] Support: 7
# Item Set: [19, 2] Support: 12
# Item Set: [19, 5] Support: 10
# Item Set: [19, 15] Support: 13
# Item Set: [19, 15, 11] Support: 4
# Item Set: [19, 15, 81] Support: 4
# Item Set: [19, 17] Support: 19
# Item Set: [19, 17, 59] Support: 4
# Item Set: [19, 17, 113] Support: 7
# Item Set: [19, 17, 81] Support: 5
# Item Set: [19, 17, 27] Support: 4
# Item Set: [19, 17, 35] Support: 6
# Item Set: [19, 29] Support: 13
# Item Set: [19, 29, 93] Support: 4
# Item Set: [19, 43] Support: 13
# Item Set: [19, 84] Support: 16
# Item Set: [19, 84, 114] Support: 4
# Item Set: [19, 84, 59] Support: 5
# Item Set: [19, 84, 93] Support: 5
# Item Set: [19, 84, 18] Support: 5
# Item Set: [19, 84, 25] Support: 4
# Item Set: [19, 84, 20] Support: 4
# Item Set: [19, 107] Support: 10
# Item Set: [19, 107, 81] Support: 4
# Item Set: [19, 107, 89] Support: 4
# Item Set: [19, 114] Support: 8
# Item Set: [19, 119] Support: 13
# Item Set: [19, 119, 7] Support: 4
# Item Set: [19, 119, 81] Support: 4
# Item Set: [19, 119, 78] Support: 4
# Item Set: [19, 11] Support: 12
# Item Set: [19, 59] Support: 14
# Item Set: [19, 59, 64] Support: 4
# Item Set: [19, 1] Support: 8
# Item Set: [19, 1, 20] Support: 4
# Item Set: [19, 4] Support: 13
# Item Set: [19, 4, 64] Support: 5
# Item Set: [19, 7] Support: 14
# Item Set: [19, 7, 98] Support: 4
# Item Set: [19, 7, 109] Support: 4
# Item Set: [19, 7, 20] Support: 4
# Item Set: [19, 49] Support: 13
# Item Set: [19, 83] Support: 11
# Item Set: [19, 83, 76] Support: 4
# Item Set: [19, 113] Support: 16
# Item Set: [19, 113, 8] Support: 6
# Item Set: [19, 60] Support: 12
# Item Set: [19, 60, 20] Support: 4
# Item Set: [19, 81] Support: 15
# Item Set: [19, 81, 76] Support: 4
# Item Set: [19, 98] Support: 10
# Item Set: [19, 98, 111] Support: 4
# Item Set: [19, 99] Support: 7
# Item Set: [19, 39] Support: 10
# Item Set: [19, 39, 76] Support: 4
# Item Set: [19, 64] Support: 14
# Item Set: [19, 64, 106] Support: 4
# Item Set: [19, 93] Support: 17
# Item Set: [19, 93, 20] Support: 5
# Item Set: [19, 106] Support: 12
# Item Set: [19, 23] Support: 10
# Item Set: [19, 23, 78] Support: 4
# Item Set: [19, 76] Support: 16
# Item Set: [19, 78] Support: 12
# Item Set: [19, 78, 27] Support: 4
# Item Set: [19, 27] Support: 12
# Item Set: [19, 27, 89] Support: 4
# Item Set: [19, 18] Support: 9
# Item Set: [19, 35] Support: 11
# Item Set: [19, 89] Support: 11
# Item Set: [19, 8] Support: 11
# Item Set: [19, 40] Support: 6
# Item Set: [19, 91] Support: 9
# Item Set: [19, 109] Support: 14
# Item Set: [19, 111] Support: 10
# Item Set: [19, 61] Support: 8
# Item Set: [19, 82] Support: 8
# Item Set: [19, 33] Support: 8
# Item Set: [19, 51] Support: 10
# Item Set: [19, 14] Support: 12
# Item Set: [19, 25] Support: 9
# Item Set: [19, 20] Support: 13
# Item Set: [19, 16] Support: 8
# Item Set: [19, 45] Support: 4
# Item Set: [21] Support: 105
# Item Set: [21, 42] Support: 7
# Item Set: [21, 42, 83] Support: 4
# Item Set: [21, 62] Support: 11
# Item Set: [21, 62, 120] Support: 4
# Item Set: [21, 62, 59] Support: 4
# Item Set: [21, 62, 7] Support: 4
# Item Set: [21, 62, 89] Support: 5
# Item Set: [21, 72] Support: 11
# Item Set: [21, 72, 120] Support: 4
# Item Set: [21, 72, 97] Support: 4
# Item Set: [21, 72, 84] Support: 4
# Item Set: [21, 72, 1] Support: 4
# Item Set: [21, 74] Support: 15
# Item Set: [21, 74, 92] Support: 4
# Item Set: [21, 74, 22] Support: 5
# Item Set: [21, 74, 36] Support: 5
# Item Set: [21, 74, 103] Support: 4
# Item Set: [21, 74, 117] Support: 4
# Item Set: [21, 74, 97] Support: 5
# Item Set: [21, 74, 2] Support: 4
# Item Set: [21, 74, 7] Support: 4
# Item Set: [21, 74, 83] Support: 4
# Item Set: [21, 74, 93] Support: 4
# Item Set: [21, 74, 33] Support: 4
# Item Set: [21, 80] Support: 13
# Item Set: [21, 80, 41] Support: 4
# Item Set: [21, 80, 11] Support: 4
# Item Set: [21, 92] Support: 15
# Item Set: [21, 92, 120] Support: 5
# Item Set: [21, 92, 43] Support: 4
# Item Set: [21, 92, 119] Support: 4
# Item Set: [21, 92, 93] Support: 5
# Item Set: [21, 92, 33] Support: 4
# Item Set: [21, 94] Support: 10
# Item Set: [21, 112] Support: 9
# Item Set: [21, 120] Support: 12
# Item Set: [21, 120, 117] Support: 5
# Item Set: [21, 120, 15] Support: 4
# Item Set: [21, 120, 7] Support: 4
# Item Set: [21, 120, 61] Support: 4
# Item Set: [21, 6] Support: 9
# Item Set: [21, 41] Support: 11
# Item Set: [21, 41, 85] Support: 4
# Item Set: [21, 41, 7] Support: 4
# Item Set: [21, 41, 98] Support: 4
# Item Set: [21, 57] Support: 14
# Item Set: [21, 57, 97] Support: 4
# Item Set: [21, 57, 93] Support: 4
# Item Set: [21, 57, 111] Support: 4
# Item Set: [21, 88] Support: 11
# Item Set: [21, 104] Support: 8
# Item Set: [21, 104, 90] Support: 4
# Item Set: [21, 116] Support: 8
# Item Set: [21, 118] Support: 10
# Item Set: [21, 118, 117] Support: 4
# Item Set: [21, 9] Support: 9
# Item Set: [21, 9, 85] Support: 4
# Item Set: [21, 22] Support: 9
# Item Set: [21, 26] Support: 6
# Item Set: [21, 36] Support: 15
# Item Set: [21, 36, 97] Support: 4
# Item Set: [21, 36, 105] Support: 5
# Item Set: [21, 36, 82] Support: 5
# Item Set: [21, 48] Support: 12
# Item Set: [21, 48, 117] Support: 4
# Item Set: [21, 48, 84] Support: 4
# Item Set: [21, 48, 114] Support: 4
# Item Set: [21, 48, 93] Support: 4
# Item Set: [21, 48, 91] Support: 4
# Item Set: [21, 90] Support: 12
# Item Set: [21, 103] Support: 18
# Item Set: [21, 103, 117] Support: 6
# Item Set: [21, 103, 117, 114] Support: 4
# Item Set: [21, 103, 85] Support: 4
# Item Set: [21, 103, 97] Support: 4
# Item Set: [21, 103, 114] Support: 5
# Item Set: [21, 103, 11] Support: 4
# Item Set: [21, 103, 1] Support: 4
# Item Set: [21, 103, 7] Support: 5
# Item Set: [21, 103, 61] Support: 4
# Item Set: [21, 103, 25] Support: 4
# Item Set: [21, 117] Support: 14
# Item Set: [21, 117, 15] Support: 4
# Item Set: [21, 117, 107] Support: 5
# Item Set: [21, 117, 114] Support: 5
# Item Set: [21, 117, 119] Support: 4
# Item Set: [21, 53] Support: 17
# Item Set: [21, 53, 85] Support: 4
# Item Set: [21, 53, 98] Support: 4
# Item Set: [21, 53, 61] Support: 5
# Item Set: [21, 53, 33] Support: 4
# Item Set: [21, 53, 25] Support: 4
# Item Set: [21, 70] Support: 14
# Item Set: [21, 70, 105] Support: 4
# Item Set: [21, 70, 60] Support: 4
# Item Set: [21, 70, 91] Support: 4
# Item Set: [21, 85] Support: 12
# Item Set: [21, 97] Support: 16
# Item Set: [21, 97, 17] Support: 4
# Item Set: [21, 97, 43] Support: 4
# Item Set: [21, 97, 23] Support: 6
# Item Set: [21, 97, 89] Support: 4
# Item Set: [21, 105] Support: 16
# Item Set: [21, 105, 119] Support: 4
# Item Set: [21, 105, 111] Support: 4
# Item Set: [21, 105, 61] Support: 4
# Item Set: [21, 2] Support: 13
# Item Set: [21, 2, 61] Support: 4
# Item Set: [21, 5] Support: 8
# Item Set: [21, 15] Support: 12
# Item Set: [21, 15, 11] Support: 4
# Item Set: [21, 15, 35] Support: 4
# Item Set: [21, 17] Support: 11
# Item Set: [21, 17, 89] Support: 4
# Item Set: [21, 17, 91] Support: 5
# Item Set: [21, 29] Support: 5
# Item Set: [21, 43] Support: 12
# Item Set: [21, 84] Support: 14
# Item Set: [21, 84, 1] Support: 4
# Item Set: [21, 84, 39] Support: 4
# Item Set: [21, 84, 33] Support: 4
# Item Set: [21, 107] Support: 11
# Item Set: [21, 107, 61] Support: 4
# Item Set: [21, 114] Support: 12
# Item Set: [21, 114, 18] Support: 4
# Item Set: [21, 119] Support: 12
# Item Set: [21, 11] Support: 16
# Item Set: [21, 11, 1] Support: 4
# Item Set: [21, 11, 27] Support: 4
# Item Set: [21, 59] Support: 10
# Item Set: [21, 1] Support: 14
# Item Set: [21, 1, 35] Support: 4
# Item Set: [21, 1, 82] Support: 4
# Item Set: [21, 4] Support: 10
# Item Set: [21, 4, 35] Support: 4
# Item Set: [21, 7] Support: 15
# Item Set: [21, 7, 83] Support: 4
# Item Set: [21, 7, 60] Support: 4
# Item Set: [21, 7, 89] Support: 4
# Item Set: [21, 49] Support: 8
# Item Set: [21, 83] Support: 13
# Item Set: [21, 83, 89] Support: 4
# Item Set: [21, 113] Support: 9
# Item Set: [21, 60] Support: 10
# Item Set: [21, 81] Support: 9
# Item Set: [21, 98] Support: 13
# Item Set: [21, 99] Support: 6
# Item Set: [21, 39] Support: 8
# Item Set: [21, 64] Support: 10
# Item Set: [21, 64, 111] Support: 5
# Item Set: [21, 93] Support: 9
# Item Set: [21, 106] Support: 8
# Item Set: [21, 23] Support: 13
# Item Set: [21, 23, 61] Support: 4
# Item Set: [21, 76] Support: 9
# Item Set: [21, 78] Support: 11
# Item Set: [21, 27] Support: 7
# Item Set: [21, 18] Support: 13
# Item Set: [21, 35] Support: 11
# Item Set: [21, 89] Support: 12
# Item Set: [21, 8] Support: 6
# Item Set: [21, 40] Support: 8
# Item Set: [21, 91] Support: 9
# Item Set: [21, 109] Support: 5
# Item Set: [21, 111] Support: 13
# Item Set: [21, 61] Support: 14
# Item Set: [21, 61, 25] Support: 4
# Item Set: [21, 82] Support: 12
# Item Set: [21, 33] Support: 11
# Item Set: [21, 51] Support: 9
# Item Set: [21, 14] Support: 9
# Item Set: [21, 25] Support: 10
# Item Set: [21, 20] Support: 9
# Item Set: [21, 16] Support: 6
# Item Set: [21, 45] Support: 7
# Item Set: [42] Support: 105
# Item Set: [42, 62] Support: 4
# Item Set: [42, 72] Support: 11
# Item Set: [42, 72, 41] Support: 4
# Item Set: [42, 74] Support: 6
# Item Set: [42, 80] Support: 15
# Item Set: [42, 80, 92] Support: 4
# Item Set: [42, 80, 117] Support: 5
# Item Set: [42, 80, 39] Support: 4
# Item Set: [42, 92] Support: 12
# Item Set: [42, 92, 103] Support: 5
# Item Set: [42, 92, 61] Support: 4
# Item Set: [42, 92, 20] Support: 4
# Item Set: [42, 94] Support: 13
# Item Set: [42, 94, 5] Support: 4
# Item Set: [42, 94, 5, 78] Support: 4
# Item Set: [42, 94, 107] Support: 4
# Item Set: [42, 94, 49] Support: 4
# Item Set: [42, 94, 81] Support: 4
# Item Set: [42, 94, 78] Support: 5
# Item Set: [42, 112] Support: 11
# Item Set: [42, 112, 5] Support: 4
# Item Set: [42, 112, 89] Support: 4
# Item Set: [42, 120] Support: 9
# Item Set: [42, 120, 109] Support: 4
# Item Set: [42, 6] Support: 11
# Item Set: [42, 6, 36] Support: 4
# Item Set: [42, 41] Support: 17
# Item Set: [42, 41, 9] Support: 4
# Item Set: [42, 41, 5] Support: 4
# Item Set: [42, 41, 98] Support: 6
# Item Set: [42, 41, 78] Support: 4
# Item Set: [42, 41, 18] Support: 4
# Item Set: [42, 41, 40] Support: 4
# Item Set: [42, 57] Support: 14
# Item Set: [42, 57, 78] Support: 4
# Item Set: [42, 57, 89] Support: 4
# Item Set: [42, 88] Support: 11
# Item Set: [42, 88, 99] Support: 5
# Item Set: [42, 104] Support: 18
# Item Set: [42, 104, 116] Support: 4
# Item Set: [42, 104, 48] Support: 6
# Item Set: [42, 104, 105] Support: 4
# Item Set: [42, 104, 2] Support: 6
# Item Set: [42, 104, 99] Support: 4
# Item Set: [42, 104, 106] Support: 4
# Item Set: [42, 104, 109] Support: 4
# Item Set: [42, 116] Support: 11
# Item Set: [42, 116, 9] Support: 5
# Item Set: [42, 116, 117] Support: 4
# Item Set: [42, 116, 39] Support: 4
# Item Set: [42, 118] Support: 11
# Item Set: [42, 118, 59] Support: 4
# Item Set: [42, 118, 98] Support: 4
# Item Set: [42, 9] Support: 18
# Item Set: [42, 9, 36] Support: 4
# Item Set: [42, 9, 85] Support: 4
# Item Set: [42, 9, 105] Support: 4
# Item Set: [42, 9, 5] Support: 5
# Item Set: [42, 9, 107] Support: 6
# Item Set: [42, 9, 83] Support: 4
# Item Set: [42, 9, 39] Support: 4
# Item Set: [42, 9, 78] Support: 5
# Item Set: [42, 9, 82] Support: 4
# Item Set: [42, 22] Support: 8
# Item Set: [42, 22, 83] Support: 5
# Item Set: [42, 26] Support: 11
# Item Set: [42, 26, 36] Support: 5
# Item Set: [42, 36] Support: 11
# Item Set: [42, 36, 93] Support: 4
# Item Set: [42, 48] Support: 15
# Item Set: [42, 48, 70] Support: 4
# Item Set: [42, 48, 59] Support: 5
# Item Set: [42, 48, 99] Support: 4
# Item Set: [42, 90] Support: 12
# Item Set: [42, 90, 60] Support: 4
# Item Set: [42, 90, 106] Support: 4
# Item Set: [42, 90, 78] Support: 5
# Item Set: [42, 103] Support: 10
# Item Set: [42, 117] Support: 14
# Item Set: [42, 117, 70] Support: 4
# Item Set: [42, 117, 107] Support: 5
# Item Set: [42, 117, 83] Support: 5
# Item Set: [42, 117, 113] Support: 4
# Item Set: [42, 53] Support: 7
# Item Set: [42, 70] Support: 10
# Item Set: [42, 85] Support: 9
# Item Set: [42, 85, 107] Support: 4
# Item Set: [42, 97] Support: 8
# Item Set: [42, 97, 107] Support: 4
# Item Set: [42, 105] Support: 13
# Item Set: [42, 105, 107] Support: 4
# Item Set: [42, 105, 82] Support: 4
# Item Set: [42, 2] Support: 9
# Item Set: [42, 5] Support: 15
# Item Set: [42, 5, 83] Support: 4
# Item Set: [42, 5, 78] Support: 6
# Item Set: [42, 5, 61] Support: 4
# Item Set: [42, 15] Support: 10
# Item Set: [42, 17] Support: 11
# Item Set: [42, 17, 60] Support: 4
# Item Set: [42, 29] Support: 13
# Item Set: [42, 43] Support: 11
# Item Set: [42, 84] Support: 10
# Item Set: [42, 84, 18] Support: 4
# Item Set: [42, 84, 20] Support: 5
# Item Set: [42, 107] Support: 19
# Item Set: [42, 107, 59] Support: 4
# Item Set: [42, 107, 49] Support: 4
# Item Set: [42, 107, 113] Support: 5
# Item Set: [42, 107, 99] Support: 4
# Item Set: [42, 107, 39] Support: 4
# Item Set: [42, 107, 78] Support: 4
# Item Set: [42, 114] Support: 4
# Item Set: [42, 119] Support: 8
# Item Set: [42, 11] Support: 11
# Item Set: [42, 59] Support: 12
# Item Set: [42, 59, 39] Support: 5
# Item Set: [42, 1] Support: 5
# Item Set: [42, 4] Support: 11
# Item Set: [42, 7] Support: 8
# Item Set: [42, 49] Support: 8
# Item Set: [42, 83] Support: 17
# Item Set: [42, 83, 39] Support: 5
# Item Set: [42, 83, 93] Support: 5
# Item Set: [42, 83, 82] Support: 6
# Item Set: [42, 83, 82, 20] Support: 4
# Item Set: [42, 83, 20] Support: 6
# Item Set: [42, 113] Support: 11
# Item Set: [42, 60] Support: 11
# Item Set: [42, 60, 78] Support: 4
# Item Set: [42, 81] Support: 10
# Item Set: [42, 81, 25] Support: 4
# Item Set: [42, 98] Support: 13
# Item Set: [42, 99] Support: 16
# Item Set: [42, 99, 93] Support: 4
# Item Set: [42, 99, 111] Support: 4
# Item Set: [42, 39] Support: 15
# Item Set: [42, 39, 78] Support: 4
# Item Set: [42, 64] Support: 6
# Item Set: [42, 93] Support: 17
# Item Set: [42, 106] Support: 16
# Item Set: [42, 106, 16] Support: 4
# Item Set: [42, 23] Support: 7
# Item Set: [42, 76] Support: 8
# Item Set: [42, 78] Support: 17
# Item Set: [42, 27] Support: 14
# Item Set: [42, 27, 8] Support: 4
# Item Set: [42, 18] Support: 8
# Item Set: [42, 35] Support: 8
# Item Set: [42, 89] Support: 10
# Item Set: [42, 8] Support: 10
# Item Set: [42, 40] Support: 10
# Item Set: [42, 91] Support: 9
# Item Set: [42, 109] Support: 9
# Item Set: [42, 111] Support: 9
# Item Set: [42, 61] Support: 11
# Item Set: [42, 82] Support: 12
# Item Set: [42, 82, 20] Support: 5
# Item Set: [42, 33] Support: 10
# Item Set: [42, 51] Support: 8
# Item Set: [42, 14] Support: 6
# Item Set: [42, 25] Support: 9
# Item Set: [42, 20] Support: 14
# Item Set: [42, 16] Support: 8
# Item Set: [42, 45] Support: 8
# Item Set: [62] Support: 105
# Item Set: [62, 72] Support: 9
# Item Set: [62, 72, 59] Support: 4
# Item Set: [62, 74] Support: 11
# Item Set: [62, 74, 94] Support: 4
# Item Set: [62, 80] Support: 11
# Item Set: [62, 80, 112] Support: 4
# Item Set: [62, 92] Support: 12
# Item Set: [62, 92, 120] Support: 4
# Item Set: [62, 92, 98] Support: 4
# Item Set: [62, 92, 23] Support: 4
# Item Set: [62, 94] Support: 10
# Item Set: [62, 94, 88] Support: 4
# Item Set: [62, 112] Support: 19
# Item Set: [62, 112, 88] Support: 4
# Item Set: [62, 112, 104] Support: 4
# Item Set: [62, 112, 48] Support: 4
# Item Set: [62, 112, 53] Support: 4
# Item Set: [62, 112, 15] Support: 6
# Item Set: [62, 112, 43] Support: 4
# Item Set: [62, 112, 107] Support: 4
# Item Set: [62, 112, 59] Support: 4
# Item Set: [62, 112, 83] Support: 4
# Item Set: [62, 112, 23] Support: 4
# Item Set: [62, 112, 76] Support: 4
# Item Set: [62, 112, 18] Support: 4
# Item Set: [62, 112, 91] Support: 4
# Item Set: [62, 112, 16] Support: 4
# Item Set: [62, 120] Support: 15
# Item Set: [62, 120, 104] Support: 4
# Item Set: [62, 120, 22] Support: 4
# Item Set: [62, 120, 1] Support: 4
# Item Set: [62, 120, 7] Support: 5
# Item Set: [62, 120, 35] Support: 4
# Item Set: [62, 120, 20] Support: 4
# Item Set: [62, 6] Support: 17
# Item Set: [62, 6, 90] Support: 5
# Item Set: [62, 6, 97] Support: 4
# Item Set: [62, 6, 7] Support: 4
# Item Set: [62, 41] Support: 11
# Item Set: [62, 41, 16] Support: 4
# Item Set: [62, 57] Support: 11
# Item Set: [62, 57, 17] Support: 4
# Item Set: [62, 88] Support: 14
# Item Set: [62, 88, 104] Support: 4
# Item Set: [62, 88, 16] Support: 4
# Item Set: [62, 104] Support: 13
# Item Set: [62, 104, 15] Support: 4
# Item Set: [62, 104, 17] Support: 4
# Item Set: [62, 104, 83] Support: 4
# Item Set: [62, 104, 113] Support: 4
# Item Set: [62, 104, 20] Support: 4
# Item Set: [62, 116] Support: 10
# Item Set: [62, 118] Support: 12
# Item Set: [62, 118, 76] Support: 4
# Item Set: [62, 118, 109] Support: 4
# Item Set: [62, 9] Support: 11
# Item Set: [62, 9, 22] Support: 4
# Item Set: [62, 9, 39] Support: 4
# Item Set: [62, 9, 109] Support: 5
# Item Set: [62, 22] Support: 17
# Item Set: [62, 22, 90] Support: 4
# Item Set: [62, 22, 103] Support: 4
# Item Set: [62, 22, 53] Support: 4
# Item Set: [62, 22, 5] Support: 4
# Item Set: [62, 22, 43] Support: 4
# Item Set: [62, 22, 59] Support: 5
# Item Set: [62, 22, 40] Support: 4
# Item Set: [62, 22, 109] Support: 4
# Item Set: [62, 22, 111] Support: 5
# Item Set: [62, 22, 14] Support: 4
# Item Set: [62, 22, 25] Support: 5
# Item Set: [62, 26] Support: 13
# Item Set: [62, 26, 15] Support: 4
# Item Set: [62, 26, 109] Support: 4
# Item Set: [62, 36] Support: 13
# Item Set: [62, 36, 85] Support: 4
# Item Set: [62, 36, 89] Support: 4
# Item Set: [62, 36, 61] Support: 4
# Item Set: [62, 48] Support: 12
# Item Set: [62, 48, 59] Support: 4
# Item Set: [62, 90] Support: 14
# Item Set: [62, 90, 20] Support: 4
# Item Set: [62, 103] Support: 13
# Item Set: [62, 103, 84] Support: 4
# Item Set: [62, 103, 18] Support: 4
# Item Set: [62, 117] Support: 11
# Item Set: [62, 117, 14] Support: 4
# Item Set: [62, 53] Support: 14
# Item Set: [62, 53, 59] Support: 4
# Item Set: [62, 53, 78] Support: 5
# Item Set: [62, 53, 82] Support: 4
# Item Set: [62, 53, 25] Support: 4
# Item Set: [62, 53, 20] Support: 4
# Item Set: [62, 70] Support: 6
# Item Set: [62, 85] Support: 10
# Item Set: [62, 85, 82] Support: 4
# Item Set: [62, 97] Support: 11
# Item Set: [62, 97, 40] Support: 5
# Item Set: [62, 105] Support: 4
# Item Set: [62, 2] Support: 11
# Item Set: [62, 5] Support: 11
# Item Set: [62, 15] Support: 11
# Item Set: [62, 17] Support: 12
# Item Set: [62, 29] Support: 8
# Item Set: [62, 43] Support: 9
# Item Set: [62, 43, 59] Support: 6
# Item Set: [62, 84] Support: 8
# Item Set: [62, 107] Support: 13
# Item Set: [62, 107, 39] Support: 4
# Item Set: [62, 107, 39, 109] Support: 4
# Item Set: [62, 107, 76] Support: 6
# Item Set: [62, 107, 109] Support: 4
# Item Set: [62, 114] Support: 8
# Item Set: [62, 119] Support: 12
# Item Set: [62, 119, 111] Support: 4
# Item Set: [62, 11] Support: 10
# Item Set: [62, 11, 40] Support: 4
# Item Set: [62, 59] Support: 17
# Item Set: [62, 59, 14] Support: 4
# Item Set: [62, 1] Support: 10
# Item Set: [62, 1, 16] Support: 4
# Item Set: [62, 4] Support: 5
# Item Set: [62, 7] Support: 15
# Item Set: [62, 7, 35] Support: 4
# Item Set: [62, 7, 45] Support: 4
# Item Set: [62, 49] Support: 8
# Item Set: [62, 83] Support: 11
# Item Set: [62, 83, 23] Support: 4
# Item Set: [62, 113] Support: 11
# Item Set: [62, 113, 109] Support: 4
# Item Set: [62, 60] Support: 13
# Item Set: [62, 60, 111] Support: 5
# Item Set: [62, 60, 111, 25] Support: 4
# Item Set: [62, 60, 25] Support: 4
# Item Set: [62, 81] Support: 11
# Item Set: [62, 81, 76] Support: 4
# Item Set: [62, 98] Support: 8
# Item Set: [62, 99] Support: 7
# Item Set: [62, 39] Support: 12
# Item Set: [62, 39, 76] Support: 5
# Item Set: [62, 39, 109] Support: 5
# Item Set: [62, 39, 25] Support: 4
# Item Set: [62, 64] Support: 9
# Item Set: [62, 64, 78] Support: 4
# Item Set: [62, 64, 40] Support: 4
# Item Set: [62, 64, 109] Support: 4
# Item Set: [62, 93] Support: 14
# Item Set: [62, 93, 76] Support: 4
# Item Set: [62, 93, 20] Support: 4
# Item Set: [62, 93, 16] Support: 5
# Item Set: [62, 106] Support: 11
# Item Set: [62, 106, 89] Support: 4
# Item Set: [62, 106, 91] Support: 4
# Item Set: [62, 23] Support: 10
# Item Set: [62, 76] Support: 16
# Item Set: [62, 76, 109] Support: 4
# Item Set: [62, 78] Support: 12
# Item Set: [62, 27] Support: 9
# Item Set: [62, 18] Support: 11
# Item Set: [62, 35] Support: 8
# Item Set: [62, 89] Support: 13
# Item Set: [62, 89, 91] Support: 4
# Item Set: [62, 8] Support: 8
# Item Set: [62, 8, 111] Support: 4
# Item Set: [62, 40] Support: 12
# Item Set: [62, 91] Support: 14
# Item Set: [62, 109] Support: 15
# Item Set: [62, 109, 20] Support: 4
# Item Set: [62, 111] Support: 14
# Item Set: [62, 111, 25] Support: 6
# Item Set: [62, 61] Support: 10
# Item Set: [62, 82] Support: 8
# Item Set: [62, 33] Support: 7
# Item Set: [62, 51] Support: 6
# Item Set: [62, 14] Support: 10
# Item Set: [62, 25] Support: 14
# Item Set: [62, 20] Support: 14
# Item Set: [62, 16] Support: 15
# Item Set: [62, 45] Support: 10
# Item Set: [72] Support: 105
# Item Set: [72, 74] Support: 10
# Item Set: [72, 74, 119] Support: 4
# Item Set: [72, 80] Support: 7
# Item Set: [72, 92] Support: 13
# Item Set: [72, 92, 116] Support: 4
# Item Set: [72, 92, 60] Support: 4
# Item Set: [72, 94] Support: 17
# Item Set: [72, 94, 88] Support: 4
# Item Set: [72, 94, 105] Support: 5
# Item Set: [72, 94, 59] Support: 4
# Item Set: [72, 94, 83] Support: 4
# Item Set: [72, 112] Support: 13
# Item Set: [72, 112, 41] Support: 4
# Item Set: [72, 112, 61] Support: 4
# Item Set: [72, 120] Support: 13
# Item Set: [72, 120, 97] Support: 4
# Item Set: [72, 120, 17] Support: 4
# Item Set: [72, 120, 89] Support: 5
# Item Set: [72, 6] Support: 9
# Item Set: [72, 41] Support: 13
# Item Set: [72, 41, 70] Support: 4
# Item Set: [72, 41, 60] Support: 4
# Item Set: [72, 41, 78] Support: 4
# Item Set: [72, 57] Support: 12
# Item Set: [72, 88] Support: 10
# Item Set: [72, 88, 11] Support: 4
# Item Set: [72, 104] Support: 12
# Item Set: [72, 116] Support: 14
# Item Set: [72, 118] Support: 11
# Item Set: [72, 9] Support: 14
# Item Set: [72, 9, 103] Support: 4
# Item Set: [72, 9, 85] Support: 4
# Item Set: [72, 9, 11] Support: 4
# Item Set: [72, 9, 64] Support: 4
# Item Set: [72, 9, 8] Support: 4
# Item Set: [72, 22] Support: 12
# Item Set: [72, 22, 26] Support: 4
# Item Set: [72, 22, 59] Support: 4
# Item Set: [72, 22, 7] Support: 4
# Item Set: [72, 22, 109] Support: 4
# Item Set: [72, 26] Support: 15
# Item Set: [72, 26, 85] Support: 5
# Item Set: [72, 26, 7] Support: 4
# Item Set: [72, 26, 61] Support: 4
# Item Set: [72, 36] Support: 7
# Item Set: [72, 48] Support: 12
# Item Set: [72, 48, 113] Support: 4
# Item Set: [72, 90] Support: 10
# Item Set: [72, 103] Support: 10
# Item Set: [72, 103, 82] Support: 4
# Item Set: [72, 117] Support: 9
# Item Set: [72, 53] Support: 10
# Item Set: [72, 53, 85] Support: 4
# Item Set: [72, 53, 61] Support: 4
# Item Set: [72, 70] Support: 17
# Item Set: [72, 70, 105] Support: 4
# Item Set: [72, 70, 17] Support: 4
# Item Set: [72, 70, 119] Support: 4
# Item Set: [72, 85] Support: 14
# Item Set: [72, 85, 119] Support: 4
# Item Set: [72, 85, 4] Support: 5
# Item Set: [72, 97] Support: 10
# Item Set: [72, 97, 17] Support: 4
# Item Set: [72, 97, 14] Support: 4
# Item Set: [72, 105] Support: 13
# Item Set: [72, 105, 35] Support: 4
# Item Set: [72, 2] Support: 11
# Item Set: [72, 2, 15] Support: 5
# Item Set: [72, 2, 8] Support: 4
# Item Set: [72, 2, 14] Support: 4
# Item Set: [72, 5] Support: 9
# Item Set: [72, 5, 49] Support: 4
# Item Set: [72, 5, 78] Support: 4
# Item Set: [72, 15] Support: 13
# Item Set: [72, 15, 7] Support: 4
# Item Set: [72, 17] Support: 13
# Item Set: [72, 17, 61] Support: 4
# Item Set: [72, 29] Support: 10
# Item Set: [72, 43] Support: 12
# Item Set: [72, 43, 39] Support: 4
# Item Set: [72, 84] Support: 13
# Item Set: [72, 84, 107] Support: 4
# Item Set: [72, 84, 11] Support: 4
# Item Set: [72, 107] Support: 12
# Item Set: [72, 107, 39] Support: 4
# Item Set: [72, 107, 8] Support: 4
# Item Set: [72, 114] Support: 9
# Item Set: [72, 114, 20] Support: 4
# Item Set: [72, 119] Support: 17
# Item Set: [72, 119, 4] Support: 4
# Item Set: [72, 119, 49] Support: 5
# Item Set: [72, 119, 39] Support: 5
# Item Set: [72, 11] Support: 14
# Item Set: [72, 11, 49] Support: 4
# Item Set: [72, 11, 91] Support: 4
# Item Set: [72, 59] Support: 15
# Item Set: [72, 59, 64] Support: 4
# Item Set: [72, 1] Support: 8
# Item Set: [72, 4] Support: 12
# Item Set: [72, 7] Support: 12
# Item Set: [72, 49] Support: 11
# Item Set: [72, 83] Support: 10
# Item Set: [72, 83, 76] Support: 4
# Item Set: [72, 83, 61] Support: 5
# Item Set: [72, 113] Support: 10
# Item Set: [72, 60] Support: 12
# Item Set: [72, 60, 82] Support: 4
# Item Set: [72, 81] Support: 9
# Item Set: [72, 98] Support: 7
# Item Set: [72, 99] Support: 12
# Item Set: [72, 39] Support: 13
# Item Set: [72, 39, 14] Support: 4
# Item Set: [72, 64] Support: 12
# Item Set: [72, 93] Support: 15
# Item Set: [72, 93, 14] Support: 4
# Item Set: [72, 106] Support: 9
# Item Set: [72, 23] Support: 10
# Item Set: [72, 23, 61] Support: 4
# Item Set: [72, 76] Support: 10
# Item Set: [72, 76, 61] Support: 5
# Item Set: [72, 76, 14] Support: 4
# Item Set: [72, 78] Support: 11
# Item Set: [72, 27] Support: 10
# Item Set: [72, 18] Support: 6
# Item Set: [72, 35] Support: 8
# Item Set: [72, 89] Support: 12
# Item Set: [72, 8] Support: 14
# Item Set: [72, 40] Support: 9
# Item Set: [72, 91] Support: 12
# Item Set: [72, 109] Support: 8
# Item Set: [72, 111] Support: 5
# Item Set: [72, 61] Support: 12
# Item Set: [72, 61, 82] Support: 4
# Item Set: [72, 82] Support: 14
# Item Set: [72, 33] Support: 8
# Item Set: [72, 51] Support: 9
# Item Set: [72, 14] Support: 13
# Item Set: [72, 25] Support: 8
# Item Set: [72, 20] Support: 12
# Item Set: [72, 16] Support: 7
# Item Set: [72, 45] Support: 5
# Item Set: [74] Support: 105
# Item Set: [74, 80] Support: 10
# Item Set: [74, 92] Support: 12
# Item Set: [74, 92, 105] Support: 4
# Item Set: [74, 92, 81] Support: 4
# Item Set: [74, 92, 93] Support: 4
# Item Set: [74, 92, 23] Support: 4
# Item Set: [74, 92, 33] Support: 5
# Item Set: [74, 94] Support: 13
# Item Set: [74, 94, 104] Support: 4
# Item Set: [74, 94, 60] Support: 4
# Item Set: [74, 94, 111] Support: 4
# Item Set: [74, 94, 51] Support: 4
# Item Set: [74, 112] Support: 8
# Item Set: [74, 120] Support: 6
# Item Set: [74, 6] Support: 12
# Item Set: [74, 6, 9] Support: 4
# Item Set: [74, 41] Support: 8
# Item Set: [74, 41, 116] Support: 5
# Item Set: [74, 41, 48] Support: 4
# Item Set: [74, 57] Support: 15
# Item Set: [74, 57, 88] Support: 4
# Item Set: [74, 57, 97] Support: 6
# Item Set: [74, 57, 4] Support: 4
# Item Set: [74, 57, 81] Support: 4
# Item Set: [74, 57, 93] Support: 4
# Item Set: [74, 57, 78] Support: 4
# Item Set: [74, 88] Support: 11
# Item Set: [74, 88, 9] Support: 5
# Item Set: [74, 104] Support: 9
# Item Set: [74, 116] Support: 13
# Item Set: [74, 116, 9] Support: 4
# Item Set: [74, 116, 61] Support: 4
# Item Set: [74, 118] Support: 9
# Item Set: [74, 118, 15] Support: 4
# Item Set: [74, 9] Support: 12
# Item Set: [74, 22] Support: 13
# Item Set: [74, 22, 15] Support: 4
# Item Set: [74, 22, 106] Support: 4
# Item Set: [74, 22, 27] Support: 4
# Item Set: [74, 26] Support: 14
# Item Set: [74, 26, 36] Support: 4
# Item Set: [74, 26, 117] Support: 4
# Item Set: [74, 26, 2] Support: 4
# Item Set: [74, 26, 23] Support: 4
# Item Set: [74, 26, 111] Support: 4
# Item Set: [74, 36] Support: 15
# Item Set: [74, 36, 111] Support: 4
# Item Set: [74, 48] Support: 13
# Item Set: [74, 48, 17] Support: 4
# Item Set: [74, 48, 93] Support: 5
# Item Set: [74, 48, 45] Support: 4
# Item Set: [74, 103] Support: 8
# Item Set: [74, 117] Support: 12
# Item Set: [74, 117, 97] Support: 5
# Item Set: [74, 117, 2] Support: 5
# Item Set: [74, 117, 107] Support: 5
# Item Set: [74, 117, 76] Support: 4
# Item Set: [74, 117, 51] Support: 4
# Item Set: [74, 117, 25] Support: 4
# Item Set: [74, 53] Support: 6
# Item Set: [74, 70] Support: 8
# Item Set: [74, 85] Support: 7
# Item Set: [74, 85, 4] Support: 4
# Item Set: [74, 97] Support: 17
# Item Set: [74, 97, 17] Support: 4
# Item Set: [74, 97, 91] Support: 4
# Item Set: [74, 97, 51] Support: 4
# Item Set: [74, 105] Support: 13
# Item Set: [74, 2] Support: 17
# Item Set: [74, 2, 84] Support: 5
# Item Set: [74, 2, 107] Support: 5
# Item Set: [74, 2, 119] Support: 5
# Item Set: [74, 2, 11] Support: 4
# Item Set: [74, 2, 39] Support: 4
# Item Set: [74, 2, 76] Support: 4
# Item Set: [74, 2, 27] Support: 4
# Item Set: [74, 2, 40] Support: 4
# Item Set: [74, 2, 25] Support: 4
# Item Set: [74, 5] Support: 9
# Item Set: [74, 15] Support: 16
# Item Set: [74, 15, 23] Support: 4
# Item Set: [74, 15, 27] Support: 5
# Item Set: [74, 17] Support: 10
# Item Set: [74, 29] Support: 10
# Item Set: [74, 43] Support: 8
# Item Set: [74, 43, 119] Support: 4
# Item Set: [74, 84] Support: 11
# Item Set: [74, 84, 39] Support: 4
# Item Set: [74, 84, 25] Support: 5
# Item Set: [74, 107] Support: 13
# Item Set: [74, 107, 49] Support: 4
# Item Set: [74, 107, 76] Support: 4
# Item Set: [74, 107, 109] Support: 4
# Item Set: [74, 107, 111] Support: 4
# Item Set: [74, 114] Support: 8
# Item Set: [74, 119] Support: 17
# Item Set: [74, 119, 11] Support: 4
# Item Set: [74, 119, 83] Support: 4
# Item Set: [74, 119, 113] Support: 4
# Item Set: [74, 119, 23] Support: 4
# Item Set: [74, 119, 33] Support: 4
# Item Set: [74, 11] Support: 13
# Item Set: [74, 11, 23] Support: 4
# Item Set: [74, 11, 27] Support: 4
# Item Set: [74, 11, 25] Support: 4
# Item Set: [74, 59] Support: 11
# Item Set: [74, 59, 93] Support: 4
# Item Set: [74, 59, 106] Support: 4
# Item Set: [74, 59, 91] Support: 4
# Item Set: [74, 1] Support: 7
# Item Set: [74, 4] Support: 10
# Item Set: [74, 7] Support: 13
# Item Set: [74, 49] Support: 15
# Item Set: [74, 49, 99] Support: 4
# Item Set: [74, 49, 93] Support: 4
# Item Set: [74, 49, 23] Support: 5
# Item Set: [74, 49, 27] Support: 5
# Item Set: [74, 49, 111] Support: 4
# Item Set: [74, 83] Support: 13
# Item Set: [74, 113] Support: 9
# Item Set: [74, 60] Support: 6
# Item Set: [74, 81] Support: 13
# Item Set: [74, 98] Support: 8
# Item Set: [74, 99] Support: 8
# Item Set: [74, 39] Support: 13
# Item Set: [74, 39, 35] Support: 4
# Item Set: [74, 39, 33] Support: 4
# Item Set: [74, 64] Support: 8
# Item Set: [74, 93] Support: 21
# Item Set: [74, 93, 35] Support: 4
# Item Set: [74, 93, 82] Support: 4
# Item Set: [74, 106] Support: 10
# Item Set: [74, 23] Support: 16
# Item Set: [74, 23, 76] Support: 6
# Item Set: [74, 76] Support: 13
# Item Set: [74, 78] Support: 13
# Item Set: [74, 27] Support: 14
# Item Set: [74, 18] Support: 10
# Item Set: [74, 35] Support: 14
# Item Set: [74, 89] Support: 9
# Item Set: [74, 8] Support: 12
# Item Set: [74, 40] Support: 9
# Item Set: [74, 91] Support: 14
# Item Set: [74, 91, 16] Support: 4
# Item Set: [74, 109] Support: 10
# Item Set: [74, 111] Support: 12
# Item Set: [74, 61] Support: 9
# Item Set: [74, 82] Support: 10
# Item Set: [74, 33] Support: 17
# Item Set: [74, 33, 14] Support: 4
# Item Set: [74, 51] Support: 11
# Item Set: [74, 14] Support: 9
# Item Set: [74, 25] Support: 14
# Item Set: [74, 20] Support: 5
# Item Set: [74, 16] Support: 13
# Item Set: [74, 45] Support: 11
# Item Set: [80] Support: 105
# Item Set: [80, 92] Support: 10
# Item Set: [80, 92, 40] Support: 4
# Item Set: [80, 94] Support: 14
# Item Set: [80, 94, 41] Support: 4
# Item Set: [80, 94, 9] Support: 4
# Item Set: [80, 94, 85] Support: 4
# Item Set: [80, 94, 105] Support: 4
# Item Set: [80, 94, 27] Support: 4
# Item Set: [80, 112] Support: 14
# Item Set: [80, 112, 11] Support: 5
# Item Set: [80, 112, 1] Support: 5
# Item Set: [80, 120] Support: 6
# Item Set: [80, 6] Support: 12
# Item Set: [80, 6, 35] Support: 4
# Item Set: [80, 41] Support: 12
# Item Set: [80, 41, 53] Support: 5
# Item Set: [80, 41, 1] Support: 5
# Item Set: [80, 57] Support: 15
# Item Set: [80, 57, 88] Support: 5
# Item Set: [80, 57, 1] Support: 4
# Item Set: [80, 57, 60] Support: 4
# Item Set: [80, 57, 45] Support: 4
# Item Set: [80, 88] Support: 16
# Item Set: [80, 88, 104] Support: 4
# Item Set: [80, 88, 85] Support: 5
# Item Set: [80, 88, 111] Support: 4
# Item Set: [80, 104] Support: 9
# Item Set: [80, 116] Support: 11
# Item Set: [80, 116, 105] Support: 4
# Item Set: [80, 116, 5] Support: 4
# Item Set: [80, 118] Support: 9
# Item Set: [80, 118, 39] Support: 4
# Item Set: [80, 9] Support: 11
# Item Set: [80, 9, 78] Support: 4
# Item Set: [80, 22] Support: 13
# Item Set: [80, 22, 97] Support: 4
# Item Set: [80, 22, 15] Support: 4
# Item Set: [80, 22, 43] Support: 6
# Item Set: [80, 22, 84] Support: 5
# Item Set: [80, 22, 7] Support: 4
# Item Set: [80, 22, 98] Support: 4
# Item Set: [80, 22, 40] Support: 4
# Item Set: [80, 26] Support: 6
# Item Set: [80, 36] Support: 12
# Item Set: [80, 36, 105] Support: 4
# Item Set: [80, 36, 89] Support: 4
# Item Set: [80, 36, 40] Support: 4
# Item Set: [80, 36, 82] Support: 5
# Item Set: [80, 48] Support: 9
# Item Set: [80, 48, 103] Support: 4
# Item Set: [80, 48, 59] Support: 4
# Item Set: [80, 48, 39] Support: 4
# Item Set: [80, 90] Support: 10
# Item Set: [80, 90, 17] Support: 4
# Item Set: [80, 103] Support: 16
# Item Set: [80, 103, 105] Support: 5
# Item Set: [80, 103, 119] Support: 4
# Item Set: [80, 103, 49] Support: 4
# Item Set: [80, 103, 60] Support: 4
# Item Set: [80, 103, 20] Support: 6
# Item Set: [80, 117] Support: 11
# Item Set: [80, 53] Support: 9
# Item Set: [80, 53, 1] Support: 4
# Item Set: [80, 70] Support: 13
# Item Set: [80, 70, 82] Support: 4
# Item Set: [80, 85] Support: 14
# Item Set: [80, 85, 59] Support: 4
# Item Set: [80, 85, 64] Support: 4
# Item Set: [80, 85, 89] Support: 4
# Item Set: [80, 97] Support: 10
# Item Set: [80, 97, 43] Support: 4
# Item Set: [80, 105] Support: 16
# Item Set: [80, 105, 1] Support: 4
# Item Set: [80, 105, 60] Support: 4
# Item Set: [80, 105, 82] Support: 5
# Item Set: [80, 2] Support: 10
# Item Set: [80, 2, 61] Support: 4
# Item Set: [80, 5] Support: 13
# Item Set: [80, 5, 45] Support: 4
# Item Set: [80, 15] Support: 14
# Item Set: [80, 15, 49] Support: 4
# Item Set: [80, 15, 35] Support: 4
# Item Set: [80, 15, 111] Support: 4
# Item Set: [80, 15, 45] Support: 4
# Item Set: [80, 17] Support: 9
# Item Set: [80, 29] Support: 9
# Item Set: [80, 43] Support: 12
# Item Set: [80, 84] Support: 13
# Item Set: [80, 107] Support: 7
# Item Set: [80, 107, 89] Support: 4
# Item Set: [80, 114] Support: 11
# Item Set: [80, 114, 111] Support: 4
# Item Set: [80, 119] Support: 9
# Item Set: [80, 11] Support: 13
# Item Set: [80, 11, 64] Support: 4
# Item Set: [80, 11, 78] Support: 4
# Item Set: [80, 11, 82] Support: 4
# Item Set: [80, 11, 33] Support: 4
# Item Set: [80, 59] Support: 14
# Item Set: [80, 59, 7] Support: 4
# Item Set: [80, 59, 39] Support: 6
# Item Set: [80, 59, 27] Support: 4
# Item Set: [80, 1] Support: 17
# Item Set: [80, 1, 4] Support: 5
# Item Set: [80, 1, 60] Support: 4
# Item Set: [80, 1, 82] Support: 4
# Item Set: [80, 4] Support: 11
# Item Set: [80, 4, 35] Support: 4
# Item Set: [80, 4, 82] Support: 5
# Item Set: [80, 7] Support: 11
# Item Set: [80, 49] Support: 10
# Item Set: [80, 83] Support: 11
# Item Set: [80, 83, 39] Support: 4
# Item Set: [80, 83, 76] Support: 4
# Item Set: [80, 113] Support: 8
# Item Set: [80, 60] Support: 14
# Item Set: [80, 60, 35] Support: 4
# Item Set: [80, 81] Support: 11
# Item Set: [80, 98] Support: 13
# Item Set: [80, 99] Support: 9
# Item Set: [80, 39] Support: 14
# Item Set: [80, 39, 76] Support: 5
# Item Set: [80, 39, 18] Support: 4
# Item Set: [80, 64] Support: 13
# Item Set: [80, 64, 18] Support: 4
# Item Set: [80, 64, 35] Support: 4
# Item Set: [80, 64, 91] Support: 4
# Item Set: [80, 93] Support: 8
# Item Set: [80, 106] Support: 7
# Item Set: [80, 23] Support: 9
# Item Set: [80, 76] Support: 13
# Item Set: [80, 76, 35] Support: 4
# Item Set: [80, 78] Support: 13
# Item Set: [80, 27] Support: 14
# Item Set: [80, 27, 111] Support: 5
# Item Set: [80, 18] Support: 10
# Item Set: [80, 35] Support: 13
# Item Set: [80, 89] Support: 11
# Item Set: [80, 8] Support: 5
# Item Set: [80, 40] Support: 14
# Item Set: [80, 40, 82] Support: 4
# Item Set: [80, 91] Support: 10
# Item Set: [80, 109] Support: 10
# Item Set: [80, 111] Support: 10
# Item Set: [80, 61] Support: 9
# Item Set: [80, 82] Support: 14
# Item Set: [80, 33] Support: 9
# Item Set: [80, 51] Support: 10
# Item Set: [80, 14] Support: 10
# Item Set: [80, 25] Support: 5
# Item Set: [80, 20] Support: 9
# Item Set: [80, 16] Support: 10
# Item Set: [80, 45] Support: 11
# Item Set: [92] Support: 105
# Item Set: [92, 94] Support: 7
# Item Set: [92, 112] Support: 21
# Item Set: [92, 112, 88] Support: 4
# Item Set: [92, 112, 85] Support: 5
# Item Set: [92, 112, 97] Support: 5
# Item Set: [92, 112, 5] Support: 4
# Item Set: [92, 112, 113] Support: 4
# Item Set: [92, 112, 98] Support: 4
# Item Set: [92, 112, 64] Support: 4
# Item Set: [92, 112, 18] Support: 4
# Item Set: [92, 112, 40] Support: 6
# Item Set: [92, 120] Support: 15
# Item Set: [92, 120, 119] Support: 4
# Item Set: [92, 120, 113] Support: 4
# Item Set: [92, 120, 23] Support: 6
# Item Set: [92, 120, 61] Support: 4
# Item Set: [92, 120, 82] Support: 4
# Item Set: [92, 120, 33] Support: 4
# Item Set: [92, 6] Support: 12
# Item Set: [92, 6, 104] Support: 4
# Item Set: [92, 6, 90] Support: 4
# Item Set: [92, 41] Support: 12
# Item Set: [92, 41, 98] Support: 4
# Item Set: [92, 57] Support: 10
# Item Set: [92, 57, 97] Support: 4
# Item Set: [92, 57, 93] Support: 4
# Item Set: [92, 88] Support: 10
# Item Set: [92, 104] Support: 9
# Item Set: [92, 104, 29] Support: 4
# Item Set: [92, 104, 35] Support: 4
# Item Set: [92, 116] Support: 13
# Item Set: [92, 116, 117] Support: 4
# Item Set: [92, 116, 15] Support: 4
# Item Set: [92, 116, 61] Support: 4
# Item Set: [92, 118] Support: 13
# Item Set: [92, 118, 48] Support: 5
# Item Set: [92, 118, 85] Support: 4
# Item Set: [92, 118, 97] Support: 5
# Item Set: [92, 118, 113] Support: 4
# Item Set: [92, 118, 109] Support: 4
# Item Set: [92, 9] Support: 10
# Item Set: [92, 22] Support: 10
# Item Set: [92, 22, 40] Support: 4
# Item Set: [92, 26] Support: 11
# Item Set: [92, 26, 2] Support: 4
# Item Set: [92, 26, 5] Support: 4
# Item Set: [92, 26, 17] Support: 4
# Item Set: [92, 36] Support: 11
# Item Set: [92, 36, 2] Support: 4
# Item Set: [92, 48] Support: 13
# Item Set: [92, 48, 113] Support: 4
# Item Set: [92, 48, 93] Support: 5
# Item Set: [92, 90] Support: 14
# Item Set: [92, 90, 103] Support: 4
# Item Set: [92, 90, 43] Support: 4
# Item Set: [92, 103] Support: 15
# Item Set: [92, 103, 117] Support: 4
# Item Set: [92, 103, 25] Support: 4
# Item Set: [92, 117] Support: 16
# Item Set: [92, 117, 53] Support: 5
# Item Set: [92, 117, 40] Support: 4
# Item Set: [92, 53] Support: 11
# Item Set: [92, 53, 17] Support: 4
# Item Set: [92, 70] Support: 10
# Item Set: [92, 85] Support: 9
# Item Set: [92, 85, 23] Support: 4
# Item Set: [92, 97] Support: 16
# Item Set: [92, 97, 84] Support: 4
# Item Set: [92, 105] Support: 12
# Item Set: [92, 105, 27] Support: 4
# Item Set: [92, 105, 82] Support: 4
# Item Set: [92, 2] Support: 13
# Item Set: [92, 5] Support: 11
# Item Set: [92, 5, 49] Support: 4
# Item Set: [92, 15] Support: 11
# Item Set: [92, 17] Support: 12
# Item Set: [92, 29] Support: 9
# Item Set: [92, 43] Support: 11
# Item Set: [92, 84] Support: 15
# Item Set: [92, 84, 82] Support: 4
# Item Set: [92, 107] Support: 8
# Item Set: [92, 114] Support: 6
# Item Set: [92, 119] Support: 10
# Item Set: [92, 119, 61] Support: 5
# Item Set: [92, 11] Support: 9
# Item Set: [92, 59] Support: 7
# Item Set: [92, 1] Support: 6
# Item Set: [92, 4] Support: 8
# Item Set: [92, 7] Support: 11
# Item Set: [92, 49] Support: 11
# Item Set: [92, 83] Support: 10
# Item Set: [92, 113] Support: 17
# Item Set: [92, 113, 99] Support: 4
# Item Set: [92, 113, 109] Support: 4
# Item Set: [92, 113, 14] Support: 4
# Item Set: [92, 113, 45] Support: 5
# Item Set: [92, 60] Support: 10
# Item Set: [92, 81] Support: 8
# Item Set: [92, 98] Support: 12
# Item Set: [92, 99] Support: 5
# Item Set: [92, 39] Support: 10
# Item Set: [92, 64] Support: 10
# Item Set: [92, 93] Support: 13
# Item Set: [92, 93, 23] Support: 4
# Item Set: [92, 106] Support: 6
# Item Set: [92, 23] Support: 14
# Item Set: [92, 23, 76] Support: 4
# Item Set: [92, 23, 82] Support: 4
# Item Set: [92, 76] Support: 8
# Item Set: [92, 78] Support: 10
# Item Set: [92, 27] Support: 13
# Item Set: [92, 18] Support: 13
# Item Set: [92, 35] Support: 9
# Item Set: [92, 89] Support: 8
# Item Set: [92, 8] Support: 8
# Item Set: [92, 40] Support: 13
# Item Set: [92, 40, 25] Support: 4
# Item Set: [92, 91] Support: 9
# Item Set: [92, 109] Support: 12
# Item Set: [92, 111] Support: 7
# Item Set: [92, 61] Support: 12
# Item Set: [92, 82] Support: 13
# Item Set: [92, 33] Support: 12
# Item Set: [92, 51] Support: 8
# Item Set: [92, 14] Support: 6
# Item Set: [92, 25] Support: 13
# Item Set: [92, 20] Support: 11
# Item Set: [92, 16] Support: 8
# Item Set: [92, 45] Support: 11
# Item Set: [94] Support: 105
# Item Set: [94, 112] Support: 11
# Item Set: [94, 112, 88] Support: 4
# Item Set: [94, 120] Support: 11
# Item Set: [94, 6] Support: 10
# Item Set: [94, 6, 15] Support: 4
# Item Set: [94, 41] Support: 15
# Item Set: [94, 41, 88] Support: 4
# Item Set: [94, 41, 90] Support: 4
# Item Set: [94, 41, 103] Support: 4
# Item Set: [94, 41, 105] Support: 4
# Item Set: [94, 41, 43] Support: 4
# Item Set: [94, 41, 84] Support: 4
# Item Set: [94, 41, 98] Support: 4
# Item Set: [94, 41, 106] Support: 4
# Item Set: [94, 57] Support: 14
# Item Set: [94, 57, 85] Support: 5
# Item Set: [94, 57, 105] Support: 4
# Item Set: [94, 57, 5] Support: 4
# Item Set: [94, 57, 107] Support: 4
# Item Set: [94, 57, 111] Support: 4
# Item Set: [94, 88] Support: 17
# Item Set: [94, 88, 85] Support: 5
# Item Set: [94, 88, 105] Support: 4
# Item Set: [94, 88, 5] Support: 4
# Item Set: [94, 88, 98] Support: 5
# Item Set: [94, 88, 16] Support: 4
# Item Set: [94, 104] Support: 15
# Item Set: [94, 104, 26] Support: 5
# Item Set: [94, 104, 105] Support: 5
# Item Set: [94, 104, 106] Support: 4
# Item Set: [94, 104, 111] Support: 4
# Item Set: [94, 116] Support: 11
# Item Set: [94, 116, 118] Support: 4
# Item Set: [94, 116, 114] Support: 4
# Item Set: [94, 118] Support: 12
# Item Set: [94, 118, 84] Support: 4
# Item Set: [94, 9] Support: 7
# Item Set: [94, 22] Support: 12
# Item Set: [94, 22, 97] Support: 4
# Item Set: [94, 22, 78] Support: 4
# Item Set: [94, 22, 33] Support: 4
# Item Set: [94, 26] Support: 11
# Item Set: [94, 36] Support: 7
# Item Set: [94, 48] Support: 7
# Item Set: [94, 90] Support: 13
# Item Set: [94, 90, 103] Support: 4
# Item Set: [94, 90, 84] Support: 4
# Item Set: [94, 103] Support: 14
# Item Set: [94, 103, 114] Support: 4
# Item Set: [94, 117] Support: 11
# Item Set: [94, 117, 83] Support: 5
# Item Set: [94, 53] Support: 14
# Item Set: [94, 53, 60] Support: 6
# Item Set: [94, 53, 51] Support: 4
# Item Set: [94, 70] Support: 8
# Item Set: [94, 85] Support: 15
# Item Set: [94, 85, 5] Support: 4
# Item Set: [94, 85, 107] Support: 4
# Item Set: [94, 85, 64] Support: 4
# Item Set: [94, 97] Support: 9
# Item Set: [94, 105] Support: 23
# Item Set: [94, 105, 15] Support: 5
# Item Set: [94, 105, 59] Support: 4
# Item Set: [94, 105, 60] Support: 6
# Item Set: [94, 105, 98] Support: 5
# Item Set: [94, 105, 64] Support: 4
# Item Set: [94, 105, 82] Support: 4
# Item Set: [94, 2] Support: 13
# Item Set: [94, 2, 107] Support: 4
# Item Set: [94, 5] Support: 14
# Item Set: [94, 5, 84] Support: 4
# Item Set: [94, 5, 78] Support: 6
# Item Set: [94, 15] Support: 13
# Item Set: [94, 15, 60] Support: 4
# Item Set: [94, 17] Support: 11
# Item Set: [94, 17, 111] Support: 4
# Item Set: [94, 29] Support: 6
# Item Set: [94, 43] Support: 8
# Item Set: [94, 84] Support: 11
# Item Set: [94, 107] Support: 11
# Item Set: [94, 114] Support: 12
# Item Set: [94, 119] Support: 16
# Item Set: [94, 11] Support: 6
# Item Set: [94, 59] Support: 11
# Item Set: [94, 59, 111] Support: 5
# Item Set: [94, 1] Support: 7
# Item Set: [94, 4] Support: 12
# Item Set: [94, 4, 81] Support: 5
# Item Set: [94, 4, 64] Support: 4
# Item Set: [94, 7] Support: 12
# Item Set: [94, 7, 81] Support: 4
# Item Set: [94, 49] Support: 7
# Item Set: [94, 83] Support: 14
# Item Set: [94, 83, 61] Support: 4
# Item Set: [94, 83, 20] Support: 4
# Item Set: [94, 113] Support: 11
# Item Set: [94, 113, 111] Support: 4
# Item Set: [94, 60] Support: 17
# Item Set: [94, 60, 99] Support: 4
# Item Set: [94, 60, 23] Support: 5
# Item Set: [94, 60, 35] Support: 4
# Item Set: [94, 60, 89] Support: 4
# Item Set: [94, 81] Support: 14
# Item Set: [94, 81, 25] Support: 4
# Item Set: [94, 98] Support: 15
# Item Set: [94, 98, 78] Support: 4
# Item Set: [94, 99] Support: 9
# Item Set: [94, 39] Support: 6
# Item Set: [94, 64] Support: 13
# Item Set: [94, 64, 78] Support: 4
# Item Set: [94, 93] Support: 8
# Item Set: [94, 106] Support: 11
# Item Set: [94, 23] Support: 12
# Item Set: [94, 23, 14] Support: 4
# Item Set: [94, 76] Support: 7
# Item Set: [94, 78] Support: 12
# Item Set: [94, 27] Support: 9
# Item Set: [94, 18] Support: 7
# Item Set: [94, 35] Support: 7
# Item Set: [94, 89] Support: 13
# Item Set: [94, 89, 45] Support: 4
# Item Set: [94, 8] Support: 10
# Item Set: [94, 40] Support: 8
# Item Set: [94, 91] Support: 12
# Item Set: [94, 91, 16] Support: 4
# Item Set: [94, 109] Support: 8
# Item Set: [94, 111] Support: 16
# Item Set: [94, 111, 14] Support: 5
# Item Set: [94, 61] Support: 11
# Item Set: [94, 82] Support: 9
# Item Set: [94, 33] Support: 10
# Item Set: [94, 51] Support: 15
# Item Set: [94, 14] Support: 12
# Item Set: [94, 25] Support: 8
# Item Set: [94, 20] Support: 9
# Item Set: [94, 16] Support: 10
# Item Set: [94, 45] Support: 10
# Item Set: [112] Support: 105
# Item Set: [112, 120] Support: 8
# Item Set: [112, 120, 17] Support: 4
# Item Set: [112, 120, 113] Support: 5
# Item Set: [112, 6] Support: 9
# Item Set: [112, 41] Support: 13
# Item Set: [112, 41, 70] Support: 4
# Item Set: [112, 41, 17] Support: 4
# Item Set: [112, 41, 106] Support: 4
# Item Set: [112, 57] Support: 11
# Item Set: [112, 57, 78] Support: 4
# Item Set: [112, 88] Support: 15
# Item Set: [112, 88, 103] Support: 5
# Item Set: [112, 88, 85] Support: 4
# Item Set: [112, 88, 49] Support: 4
# Item Set: [112, 88, 23] Support: 4
# Item Set: [112, 88, 89] Support: 4
# Item Set: [112, 104] Support: 11
# Item Set: [112, 104, 105] Support: 4
# Item Set: [112, 104, 111] Support: 4
# Item Set: [112, 104, 20] Support: 4
# Item Set: [112, 116] Support: 11
# Item Set: [112, 118] Support: 8
# Item Set: [112, 9] Support: 6
# Item Set: [112, 22] Support: 14
# Item Set: [112, 22, 26] Support: 5
# Item Set: [112, 22, 53] Support: 4
# Item Set: [112, 22, 49] Support: 4
# Item Set: [112, 22, 39] Support: 4
# Item Set: [112, 22, 78] Support: 4
# Item Set: [112, 26] Support: 15
# Item Set: [112, 26, 117] Support: 5
# Item Set: [112, 26, 117, 25] Support: 4
# Item Set: [112, 26, 97] Support: 4
# Item Set: [112, 26, 18] Support: 4
# Item Set: [112, 26, 8] Support: 4
# Item Set: [112, 26, 25] Support: 4
# Item Set: [112, 36] Support: 10
# Item Set: [112, 36, 97] Support: 4
# Item Set: [112, 48] Support: 14
# Item Set: [112, 48, 70] Support: 4
# ...
# Item Set: [83, 82, 20] Support: 5
# Item Set: [83, 33] Support: 6
# Item Set: [83, 51] Support: 7
# Item Set: [83, 14] Support: 6
# Item Set: [83, 25] Support: 7
# Item Set: [83, 20] Support: 14
# Item Set: [83, 16] Support: 6
# Item Set: [83, 45] Support: 12
# Item Set: [113] Support: 98
# Item Set: [113, 60] Support: 10
# Item Set: [113, 60, 81] Support: 4
# Item Set: [113, 60, 35] Support: 4
# Item Set: [113, 60, 45] Support: 4
# Item Set: [113, 81] Support: 12
# Item Set: [113, 81, 35] Support: 4
# Item Set: [113, 81, 40] Support: 4
# Item Set: [113, 81, 45] Support: 4
# Item Set: [113, 98] Support: 13
# Item Set: [113, 98, 91] Support: 5
# Item Set: [113, 99] Support: 16
# Item Set: [113, 99, 8] Support: 4
# Item Set: [113, 39] Support: 9
# Item Set: [113, 64] Support: 11
# Item Set: [113, 64, 109] Support: 4
# Item Set: [113, 93] Support: 4
# Item Set: [113, 106] Support: 8
# Item Set: [113, 23] Support: 8
# Item Set: [113, 76] Support: 12
# Item Set: [113, 76, 35] Support: 4
# Item Set: [113, 78] Support: 6
# Item Set: [113, 27] Support: 11
# Item Set: [113, 18] Support: 11
# Item Set: [113, 35] Support: 11
# Item Set: [113, 89] Support: 11
# Item Set: [113, 8] Support: 12
# Item Set: [113, 40] Support: 13
# Item Set: [113, 40, 20] Support: 4
# Item Set: [113, 91] Support: 8
# Item Set: [113, 109] Support: 13
# Item Set: [113, 111] Support: 10
# Item Set: [113, 61] Support: 4
# Item Set: [113, 82] Support: 6
# Item Set: [113, 33] Support: 10
# Item Set: [113, 51] Support: 7
# Item Set: [113, 14] Support: 6
# Item Set: [113, 25] Support: 7
# Item Set: [113, 20] Support: 14
# Item Set: [113, 16] Support: 7
# Item Set: [113, 45] Support: 15
# Item Set: [60] Support: 97
# Item Set: [60, 81] Support: 11
# Item Set: [60, 98] Support: 7
# Item Set: [60, 99] Support: 11
# Item Set: [60, 39] Support: 8
# Item Set: [60, 64] Support: 6
# Item Set: [60, 64, 35] Support: 4
# Item Set: [60, 93] Support: 7
# Item Set: [60, 106] Support: 6
# Item Set: [60, 23] Support: 12
# Item Set: [60, 76] Support: 8
# Item Set: [60, 78] Support: 9
# Item Set: [60, 78, 33] Support: 4
# Item Set: [60, 27] Support: 9
# Item Set: [60, 18] Support: 12
# Item Set: [60, 35] Support: 13
# Item Set: [60, 89] Support: 11
# Item Set: [60, 8] Support: 7
# Item Set: [60, 40] Support: 12
# Item Set: [60, 91] Support: 7
# Item Set: [60, 109] Support: 10
# Item Set: [60, 111] Support: 12
# Item Set: [60, 111, 25] Support: 4
# Item Set: [60, 61] Support: 9
# Item Set: [60, 82] Support: 7
# Item Set: [60, 33] Support: 12
# Item Set: [60, 33, 45] Support: 4
# Item Set: [60, 51] Support: 4
# Item Set: [60, 14] Support: 6
# Item Set: [60, 25] Support: 12
# Item Set: [60, 25, 20] Support: 4
# Item Set: [60, 20] Support: 10
# Item Set: [60, 16] Support: 9
# Item Set: [60, 45] Support: 12
# Item Set: [81] Support: 97
# Item Set: [81, 98] Support: 12
# Item Set: [81, 98, 99] Support: 4
# Item Set: [81, 99] Support: 12
# Item Set: [81, 39] Support: 11
# Item Set: [81, 64] Support: 10
# Item Set: [81, 64, 111] Support: 4
# Item Set: [81, 93] Support: 9
# Item Set: [81, 93, 61] Support: 4
# Item Set: [81, 106] Support: 6
# Item Set: [81, 23] Support: 6
# Item Set: [81, 76] Support: 11
# Item Set: [81, 76, 89] Support: 4
# Item Set: [81, 78] Support: 9
# Item Set: [81, 27] Support: 6
# Item Set: [81, 18] Support: 7
# Item Set: [81, 35] Support: 11
# Item Set: [81, 35, 109] Support: 4
# Item Set: [81, 89] Support: 12
# Item Set: [81, 40] Support: 8
# Item Set: [81, 91] Support: 9
# Item Set: [81, 109] Support: 11
# Item Set: [81, 109, 45] Support: 4
# Item Set: [81, 111] Support: 12
# Item Set: [81, 61] Support: 10
# Item Set: [81, 61, 82] Support: 4
# Item Set: [81, 82] Support: 10
# Item Set: [81, 33] Support: 10
# Item Set: [81, 51] Support: 7
# Item Set: [81, 25] Support: 13
# Item Set: [81, 25, 20] Support: 5
# Item Set: [81, 20] Support: 9
# Item Set: [81, 16] Support: 8
# Item Set: [81, 45] Support: 11
# Item Set: [98] Support: 97
# Item Set: [98, 99] Support: 17
# Item Set: [98, 39] Support: 11
# Item Set: [98, 64] Support: 8
# Item Set: [98, 93] Support: 6
# Item Set: [98, 106] Support: 8
# Item Set: [98, 23] Support: 6
# Item Set: [98, 76] Support: 6
# Item Set: [98, 78] Support: 11
# Item Set: [98, 27] Support: 11
# Item Set: [98, 18] Support: 9
# Item Set: [98, 35] Support: 8
# Item Set: [98, 89] Support: 6
# Item Set: [98, 8] Support: 10
# Item Set: [98, 8, 111] Support: 4
# Item Set: [98, 40] Support: 8
# Item Set: [98, 91] Support: 10
# Item Set: [98, 109] Support: 5
# Item Set: [98, 111] Support: 15
# Item Set: [98, 61] Support: 10
# Item Set: [98, 82] Support: 8
# Item Set: [98, 33] Support: 11
# Item Set: [98, 51] Support: 7
# Item Set: [98, 14] Support: 10
# Item Set: [98, 25] Support: 6
# Item Set: [98, 20] Support: 10
# Item Set: [98, 16] Support: 6
# Item Set: [98, 45] Support: 7
# Item Set: [99] Support: 97
# Item Set: [99, 39] Support: 12
# Item Set: [99, 39, 76] Support: 5
# Item Set: [99, 39, 33] Support: 4
# Item Set: [99, 64] Support: 8
# Item Set: [99, 93] Support: 12
# Item Set: [99, 106] Support: 7
# Item Set: [99, 106, 16] Support: 4
# Item Set: [99, 23] Support: 11
# Item Set: [99, 76] Support: 13
# Item Set: [99, 78] Support: 7
# Item Set: [99, 27] Support: 9
# Item Set: [99, 18] Support: 4
# Item Set: [99, 35] Support: 9
# Item Set: [99, 89] Support: 11
# Item Set: [99, 8] Support: 12
# Item Set: [99, 40] Support: 7
# Item Set: [99, 91] Support: 6
# Item Set: [99, 109] Support: 9
# Item Set: [99, 111] Support: 11
# Item Set: [99, 61] Support: 6
# Item Set: [99, 82] Support: 7
# Item Set: [99, 33] Support: 11
# Item Set: [99, 51] Support: 9
# Item Set: [99, 14] Support: 7
# Item Set: [99, 25] Support: 6
# Item Set: [99, 20] Support: 9
# Item Set: [99, 16] Support: 7
# Item Set: [99, 45] Support: 6
# Item Set: [39] Support: 96
# Item Set: [39, 64] Support: 9
# Item Set: [39, 93] Support: 7
# Item Set: [39, 106] Support: 7
# Item Set: [39, 23] Support: 8
# Item Set: [39, 23, 82] Support: 4
# Item Set: [39, 76] Support: 19
# Item Set: [39, 76, 109] Support: 4
# Item Set: [39, 76, 14] Support: 5
# Item Set: [39, 78] Support: 10
# Item Set: [39, 27] Support: 8
# Item Set: [39, 27, 8] Support: 4
# Item Set: [39, 18] Support: 11
# Item Set: [39, 35] Support: 12
# Item Set: [39, 35, 33] Support: 5
# Item Set: [39, 89] Support: 11
# Item Set: [39, 8] Support: 12
# Item Set: [39, 40] Support: 12
# Item Set: [39, 91] Support: 5
# Item Set: [39, 109] Support: 10
# Item Set: [39, 111] Support: 8
# Item Set: [39, 61] Support: 7
# Item Set: [39, 82] Support: 12
# Item Set: [39, 33] Support: 14
# Item Set: [39, 51] Support: 5
# Item Set: [39, 14] Support: 10
# Item Set: [39, 25] Support: 11
# Item Set: [39, 20] Support: 11
# Item Set: [39, 16] Support: 14
# Item Set: [39, 45] Support: 9
# Item Set: [64] Support: 96
# Item Set: [64, 93] Support: 5
# Item Set: [64, 106] Support: 12
# Item Set: [64, 106, 25] Support: 4
# Item Set: [64, 23] Support: 5
# Item Set: [64, 23, 111] Support: 4
# Item Set: [64, 76] Support: 8
# Item Set: [64, 78] Support: 11
# Item Set: [64, 78, 89] Support: 4
# Item Set: [64, 78, 40] Support: 4
# Item Set: [64, 27] Support: 5
# Item Set: [64, 18] Support: 9
# Item Set: [64, 35] Support: 12
# Item Set: [64, 35, 111] Support: 4
# Item Set: [64, 89] Support: 11
# Item Set: [64, 8] Support: 10
# Item Set: [64, 8, 33] Support: 4
# Item Set: [64, 40] Support: 11
# Item Set: [64, 91] Support: 10
# Item Set: [64, 109] Support: 13
# Item Set: [64, 111] Support: 17
# Item Set: [64, 61] Support: 8
# Item Set: [64, 82] Support: 10
# Item Set: [64, 33] Support: 14
# Item Set: [64, 33, 45] Support: 4
# Item Set: [64, 51] Support: 12
# Item Set: [64, 14] Support: 5
# Item Set: [64, 25] Support: 10
# Item Set: [64, 20] Support: 9
# Item Set: [64, 16] Support: 7
# Item Set: [64, 45] Support: 9
# Item Set: [93] Support: 96
# Item Set: [93, 106] Support: 11
# Item Set: [93, 23] Support: 10
# Item Set: [93, 76] Support: 11
# Item Set: [93, 78] Support: 9
# Item Set: [93, 27] Support: 10
# Item Set: [93, 27, 111] Support: 4
# Item Set: [93, 18] Support: 7
# Item Set: [93, 35] Support: 10
# Item Set: [93, 89] Support: 8
# Item Set: [93, 89, 109] Support: 4
# Item Set: [93, 8] Support: 7
# Item Set: [93, 40] Support: 11
# Item Set: [93, 40, 51] Support: 5
# Item Set: [93, 91] Support: 8
# Item Set: [93, 109] Support: 6
# Item Set: [93, 111] Support: 7
# Item Set: [93, 61] Support: 13
# Item Set: [93, 61, 82] Support: 4
# Item Set: [93, 82] Support: 10
# Item Set: [93, 33] Support: 11
# Item Set: [93, 51] Support: 11
# Item Set: [93, 14] Support: 11
# Item Set: [93, 25] Support: 6
# Item Set: [93, 20] Support: 13
# Item Set: [93, 16] Support: 11
# Item Set: [93, 45] Support: 9
# Item Set: [106] Support: 96
# Item Set: [106, 23] Support: 8
# Item Set: [106, 78] Support: 7
# Item Set: [106, 27] Support: 8
# Item Set: [106, 18] Support: 7
# Item Set: [106, 18, 20] Support: 4
# Item Set: [106, 35] Support: 7
# Item Set: [106, 89] Support: 11
# Item Set: [106, 8] Support: 5
# Item Set: [106, 40] Support: 13
# Item Set: [106, 91] Support: 13
# Item Set: [106, 109] Support: 9
# Item Set: [106, 111] Support: 7
# Item Set: [106, 61] Support: 9
# Item Set: [106, 82] Support: 7
# Item Set: [106, 33] Support: 5
# Item Set: [106, 51] Support: 7
# Item Set: [106, 14] Support: 6
# Item Set: [106, 25] Support: 10
# Item Set: [106, 20] Support: 9
# Item Set: [106, 16] Support: 16
# Item Set: [106, 45] Support: 10
# Item Set: [23] Support: 95
# Item Set: [23, 76] Support: 13
# Item Set: [23, 78] Support: 9
# Item Set: [23, 27] Support: 11
# Item Set: [23, 18] Support: 8
# Item Set: [23, 35] Support: 12
# Item Set: [23, 89] Support: 10
# Item Set: [23, 8] Support: 8
# Item Set: [23, 40] Support: 11
# Item Set: [23, 91] Support: 9
# Item Set: [23, 109] Support: 7
# Item Set: [23, 111] Support: 10
# Item Set: [23, 61] Support: 13
# Item Set: [23, 82] Support: 10
# Item Set: [23, 33] Support: 5
# Item Set: [23, 51] Support: 8
# Item Set: [23, 14] Support: 12
# Item Set: [23, 25] Support: 7
# Item Set: [23, 20] Support: 9
# Item Set: [23, 16] Support: 11
# Item Set: [23, 45] Support: 9
# Item Set: [76] Support: 95
# Item Set: [76, 78] Support: 10
# Item Set: [76, 27] Support: 8
# Item Set: [76, 18] Support: 7
# Item Set: [76, 35] Support: 11
# Item Set: [76, 89] Support: 11
# Item Set: [76, 8] Support: 8
# Item Set: [76, 40] Support: 8
# Item Set: [76, 91] Support: 8
# Item Set: [76, 109] Support: 12
# Item Set: [76, 111] Support: 5
# Item Set: [76, 61] Support: 12
# Item Set: [76, 82] Support: 9
# Item Set: [76, 33] Support: 8
# Item Set: [76, 51] Support: 9
# Item Set: [76, 14] Support: 9
# Item Set: [76, 25] Support: 9
# Item Set: [76, 20] Support: 4
# Item Set: [76, 16] Support: 9
# Item Set: [76, 45] Support: 8
# Item Set: [78] Support: 95
# Item Set: [78, 27] Support: 9
# Item Set: [78, 27, 51] Support: 4
# Item Set: [78, 18] Support: 11
# Item Set: [78, 35] Support: 12
# Item Set: [78, 35, 51] Support: 4
# Item Set: [78, 89] Support: 10
# Item Set: [78, 8] Support: 10
# Item Set: [78, 40] Support: 11
# Item Set: [78, 91] Support: 12
# Item Set: [78, 109] Support: 9
# Item Set: [78, 109, 45] Support: 5
# Item Set: [78, 111] Support: 9
# Item Set: [78, 61] Support: 11
# Item Set: [78, 82] Support: 8
# Item Set: [78, 33] Support: 10
# Item Set: [78, 51] Support: 14
# Item Set: [78, 14] Support: 11
# Item Set: [78, 25] Support: 8
# Item Set: [78, 16] Support: 9
# Item Set: [78, 45] Support: 9
# Item Set: [27] Support: 94
# Item Set: [27, 18] Support: 9
# Item Set: [27, 35] Support: 9
# Item Set: [27, 35, 51] Support: 4
# Item Set: [27, 89] Support: 12
# Item Set: [27, 8] Support: 17
# Item Set: [27, 8, 14] Support: 4
# Item Set: [27, 40] Support: 8
# Item Set: [27, 91] Support: 8
# Item Set: [27, 109] Support: 9
# Item Set: [27, 111] Support: 13
# Item Set: [27, 61] Support: 7
# Item Set: [27, 82] Support: 10
# Item Set: [27, 33] Support: 9
# Item Set: [27, 51] Support: 12
# Item Set: [27, 14] Support: 12
# Item Set: [27, 25] Support: 7
# Item Set: [27, 20] Support: 9
# Item Set: [27, 16] Support: 10
# Item Set: [27, 45] Support: 6
# Item Set: [18] Support: 93
# Item Set: [18, 35] Support: 8
# Item Set: [18, 89] Support: 10
# Item Set: [18, 8] Support: 10
# Item Set: [18, 40] Support: 7
# Item Set: [18, 91] Support: 8
# Item Set: [18, 109] Support: 8
# Item Set: [18, 111] Support: 12
# Item Set: [18, 111, 14] Support: 4
# Item Set: [18, 61] Support: 7
# Item Set: [18, 82] Support: 9
# Item Set: [18, 33] Support: 5
# Item Set: [18, 51] Support: 6
# Item Set: [18, 14] Support: 13
# Item Set: [18, 25] Support: 13
# Item Set: [18, 20] Support: 10
# Item Set: [18, 16] Support: 9
# Item Set: [18, 45] Support: 7
# Item Set: [35] Support: 93
# Item Set: [35, 89] Support: 7
# Item Set: [35, 8] Support: 5
# Item Set: [35, 40] Support: 7
# Item Set: [35, 91] Support: 7
# Item Set: [35, 109] Support: 8
# Item Set: [35, 111] Support: 8
# Item Set: [35, 61] Support: 8
# Item Set: [35, 82] Support: 9
# Item Set: [35, 33] Support: 10
# Item Set: [35, 51] Support: 12
# Item Set: [35, 14] Support: 6
# Item Set: [35, 25] Support: 6
# Item Set: [35, 20] Support: 7
# Item Set: [35, 16] Support: 8
# Item Set: [35, 45] Support: 6
# Item Set: [89] Support: 93
# Item Set: [89, 8] Support: 10
# Item Set: [89, 8, 82] Support: 4
# Item Set: [89, 40] Support: 9
# Item Set: [89, 91] Support: 9
# Item Set: [89, 109] Support: 10
# Item Set: [89, 111] Support: 8
# Item Set: [89, 61] Support: 9
# Item Set: [89, 82] Support: 11
# Item Set: [89, 33] Support: 8
# Item Set: [89, 51] Support: 9
# Item Set: [89, 14] Support: 10
# Item Set: [89, 25] Support: 7
# Item Set: [89, 16] Support: 8
# Item Set: [89, 45] Support: 10
# Item Set: [8] Support: 92
# Item Set: [8, 40] Support: 6
# Item Set: [8, 91] Support: 11
# Item Set: [8, 109] Support: 9
# Item Set: [8, 111] Support: 11
# Item Set: [8, 61] Support: 6
# Item Set: [8, 82] Support: 10
# Item Set: [8, 33] Support: 11
# Item Set: [8, 51] Support: 9
# Item Set: [8, 14] Support: 11
# Item Set: [8, 20] Support: 8
# Item Set: [8, 16] Support: 5
# Item Set: [8, 45] Support: 7
# Item Set: [40] Support: 92
# Item Set: [40, 91] Support: 10
# Item Set: [40, 91, 20] Support: 4
# Item Set: [40, 109] Support: 11
# Item Set: [40, 111] Support: 8
# Item Set: [40, 61] Support: 10
# Item Set: [40, 82] Support: 9
# Item Set: [40, 33] Support: 7
# Item Set: [40, 51] Support: 10
# Item Set: [40, 14] Support: 10
# Item Set: [40, 25] Support: 11
# Item Set: [40, 20] Support: 8
# Item Set: [40, 16] Support: 7
# Item Set: [40, 45] Support: 7
# Item Set: [91] Support: 92
# Item Set: [91, 109] Support: 9
# Item Set: [91, 111] Support: 8
# Item Set: [91, 61] Support: 11
# Item Set: [91, 82] Support: 7
# Item Set: [91, 33] Support: 8
# Item Set: [91, 51] Support: 7
# Item Set: [91, 14] Support: 7
# Item Set: [91, 25] Support: 10
# Item Set: [91, 20] Support: 15
# Item Set: [91, 16] Support: 12
# Item Set: [91, 45] Support: 5
# Item Set: [109] Support: 92
# Item Set: [109, 111] Support: 8
# Item Set: [109, 61] Support: 7
# Item Set: [109, 33] Support: 9
# Item Set: [109, 51] Support: 8
# Item Set: [109, 14] Support: 11
# Item Set: [109, 25] Support: 7
# Item Set: [109, 20] Support: 11
# Item Set: [109, 16] Support: 6
# Item Set: [109, 45] Support: 12
# Item Set: [111] Support: 92
# Item Set: [111, 61] Support: 10
# Item Set: [111, 82] Support: 8
# Item Set: [111, 33] Support: 9
# Item Set: [111, 51] Support: 10
# Item Set: [111, 14] Support: 11
# Item Set: [111, 25] Support: 13
# Item Set: [111, 20] Support: 6
# Item Set: [111, 16] Support: 5
# Item Set: [111, 45] Support: 6
# Item Set: [61] Support: 91
# Item Set: [61, 82] Support: 14
# Item Set: [61, 33] Support: 6
# Item Set: [61, 51] Support: 8
# Item Set: [61, 14] Support: 7
# Item Set: [61, 25] Support: 8
# Item Set: [61, 20] Support: 6
# Item Set: [61, 16] Support: 12
# Item Set: [61, 45] Support: 5
# Item Set: [82] Support: 91
# Item Set: [82, 33] Support: 5
# Item Set: [82, 51] Support: 10
# Item Set: [82, 14] Support: 8
# Item Set: [82, 25] Support: 7
# Item Set: [82, 20] Support: 12
# Item Set: [82, 16] Support: 10
# Item Set: [82, 45] Support: 6
# Item Set: [33] Support: 90
# Item Set: [33, 51] Support: 5
# Item Set: [33, 14] Support: 8
# Item Set: [33, 25] Support: 6
# Item Set: [33, 20] Support: 10
# Item Set: [33, 16] Support: 11
# Item Set: [33, 45] Support: 9
# Item Set: [51] Support: 89
# Item Set: [51, 14] Support: 12
# Item Set: [51, 25] Support: 6
# Item Set: [51, 20] Support: 5
# Item Set: [51, 16] Support: 5
# Item Set: [51, 45] Support: 6
# Item Set: [14] Support: 88
# Item Set: [14, 25] Support: 5
# Item Set: [14, 20] Support: 9
# Item Set: [14, 16] Support: 6
# Item Set: [14, 45] Support: 9
# Item Set: [25] Support: 86
# Item Set: [25, 20] Support: 10
# Item Set: [25, 16] Support: 7
# Item Set: [25, 45] Support: 10
# Item Set: [20] Support: 85
# Item Set: [20, 16] Support: 11
# Item Set: [20, 45] Support: 10
# Item Set: [16] Support: 84
# Item Set: [16, 45] Support: 6
# Item Set: [45] Support: 82
